# %%
import numpy as np
import pandas as pd
import time as time
import matplotlib.pyplot as plt

# %% [markdown]
# # Part A

# %%
df_fixedV = pd.read_csv('SC2001_Project2_Djikstra\AdjMatrix_FixedV_Results.csv')
df_fixedE = pd.read_csv('SC2001_Project2_Djikstra\AdjMatrix_FixedE_Results.csv')

# %%
def time_complexity(v, e):
    return v*v

# Array sizes to compare
i_values = np.arange(1000, 9900, 100)  # i from 1,000 to 9900 with step size of 100

# Calculating the time complexity for different values of V and E
fixedV_time_complexities = [time_complexity(100, i) for i in i_values]
fixedE_time_complexities = [time_complexity(i, 20000) for i in i_values]

# %%
# Plotting the time complexity (Fixed V, Varying E)
plt.figure(figsize=(16, 8))
plt.plot(i_values, fixedV_time_complexities, label='theoretical', color='red')

plt.title("Key Comparisons Over Different Number of Edges") 
plt.xlabel("Edges") 
plt.ylabel("Key Comparisons")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")

plt.plot(df_fixedV.Edges, df_fixedV.KeyComp, label = 'empirical', linestyle='--', color = 'blue')

plt.legend()

# %%
# Plotting the time complexity (Varying V, Fixed E)
plt.figure(figsize=(16, 8))
plt.plot(i_values, fixedE_time_complexities, label='theoretical', color='orange')

plt.title("Key Comparisons Over Different Number of Vertices") 
plt.xlabel("Vertices") 
plt.ylabel("Key Comparisons")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")

plt.plot(df_fixedE.Vertices, df_fixedE.KeyComp, label = 'empirical', linestyle='--', color = 'blue')

plt.legend()

# %%
# Plotting the runtime (Fixed V, Varying E)
plt.figure(figsize=(16, 8))

plt.title("Runtime Over Different Number of Edges") 
plt.xlabel("Edges") 
plt.ylabel("Runtime (ms)")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")

plt.plot(df_fixedV.Edges, df_fixedV.ElapsedTime, marker = '.')

# %%
# Plotting the runtime (Varying V, Fixed E)
plt.figure(figsize=(16, 8))

plt.title("Runtime Over Different Number of Vertices") 
plt.xlabel("Vertices") 
plt.ylabel("Runtime (ms)")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")

plt.plot(df_fixedE.Vertices, df_fixedE.ElapsedTime, marker = '.')

# %% [markdown]
# # Part B

# %%
df_fixedV_2 = pd.read_csv('SC2001_Project2_Djikstra\AdjList_FixedV_Results.csv')
df_fixedE_2 = pd.read_csv('SC2001_Project2_Djikstra\AdjList_FixedE_Results.csv')

# %%
def time_complexity(v, e):
    return (v+e) * np.log(v)

# Array sizes to compare
i_values = np.arange(1000, 9900, 100)  # i from 1,000 to 9900 with step size of 100

# Calculating the time complexity for different values of V and E
fixedV_time_complexities_2 = [time_complexity(100, i) for i in i_values]
fixedE_time_complexities_2 = [time_complexity(i, 20000) for i in i_values]

# %%
# Plotting the time complexity (Fixed V, Varying E)
plt.figure(figsize=(16, 8))
plt.plot(i_values, fixedV_time_complexities_2, label='theoretical', color='red')

plt.title("Key Comparisons Over Different Number of Edges") 
plt.xlabel("Edges") 
plt.ylabel("Key Comparisons")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")

plt.plot(df_fixedV_2.Edges, df_fixedV_2.KeyComp, marker = '.', label = 'empirical')

plt.legend()

# %%
# Plotting the time complexity (Varying V, Fixed E)
plt.figure(figsize=(16, 8))
plt.plot(i_values, fixedE_time_complexities_2, label='theoretical', color='red')

plt.title("Key Comparisons Over Different Number of Vertices") 
plt.xlabel("Vertices") 
plt.ylabel("Key Comparisons")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")

plt.plot(df_fixedE_2.Vertices, df_fixedE_2.KeyComp, marker = '.', label = 'empirical')

plt.legend()

# %%
# Plotting the runtime (Fixed V, Varying E)
plt.figure(figsize=(16, 8))

plt.title("Runtime Over Different Number of Edges") 
plt.xlabel("Edges") 
plt.ylabel("Runtime (ms)")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")

plt.plot(df_fixedV_2.Edges, df_fixedV_2.ElapsedTime, marker = '.')

# %%
# Plotting the runtime (Varying V, Fixed E)
plt.figure(figsize=(16, 8))

plt.title("Runtime Over Different Number of Vertices") 
plt.xlabel("Vertices") 
plt.ylabel("Runtime (ms)")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")

plt.plot(df_fixedE_2.Vertices, df_fixedE_2.ElapsedTime, marker = '.')

# %%
plt.figure(figsize=(16,8)) #fixed V at 100
plt.title("Runtime Over Different Number of Edges") 
plt.xlabel("Edges") 
plt.ylabel("Runtime (ms)")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")
plt.plot(df_fixedV.Edges, df_fixedV.ElapsedTime, marker = '.', color = 'blue', label = 'Matrix with Array')
plt.plot(df_fixedV_2.Edges, df_fixedV_2.ElapsedTime, marker = '.', color = 'orange', label = 'List with Heap')
plt.legend()

# %%
plt.figure(figsize=(16,8)) #fixed e at 20000
plt.title("Runtime Over Different Number of Vertices") 
plt.xlabel("Vertices") 
plt.ylabel("Runtime (ms)")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")
plt.plot(df_fixedE.Vertices, df_fixedE.ElapsedTime, marker = '.', color = 'blue')
plt.plot(df_fixedE_2.Vertices, df_fixedE_2.ElapsedTime, marker = '.', color = 'orange')

# %%
def ratio(x,y):
    return y/(x*(x-1))

xratio_1 = [ratio(100, i) for i in i_values]
i_values_2 = np.arange(1000, 10000, 100)
xratio_2 = [ratio(100, i) for i in i_values_2]

# %%
plt.figure(figsize=(16,8)) #fixed V at 100
plt.title("Runtime Over |E|/|V||V-1|") 
plt.xlabel("|E|/|V||V-1|") 
plt.ylabel("Runtime (ms)")
plt.ticklabel_format(axis="y", style="plain")
plt.ticklabel_format(axis="x", style="plain")
plt.plot(xratio_1, df_fixedV.ElapsedTime, marker = '.', color = 'blue', label = 'Matrix with Array')
plt.plot(xratio_2, df_fixedV_2.ElapsedTime, marker = '.', color = 'orange', label = 'List with Heap')
plt.legend()
