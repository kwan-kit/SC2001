# %%
import numpy as np

#change the threshold to np.inf to print everything but maximum array size allowed for the browser data limit is 100,000
np.set_printoptions(threshold=1000)

# Function to generate a random array based on input size and max value
def generate_random_array(size, max_value):
    return np.random.randint(1, max_value + 1, size)

size = 10000
max_value = 10000
random_array = generate_random_array(size, max_value)

random_array
# Out:
# array([2052, 3708, 7943, ..., 9077, 1484,   98])

# %%
import numpy as np

# Function to generate the dataset with the arrays 
def generate_datasets(limit):
    dataset = []
    sizes = [1000,10000,100000,1000000,10000000] #size of the arrays
    for size in sizes:
        dataset.append(np.random.randint(1, limit + 1, size))
    return dataset

limit = 5000  # You can specify the limit here
datasets = generate_datasets(limit)
datasets
# Out:
# [array([ 580, 2570, 1141, 3090, 4866, 1138,  617, 3166, 4363, 3901, 1601,
#         1935, 1125, 2218, 2822,  530,  226,  609, 3891, 4214, 4607, 2577,
#         3923,    8, 1880, 4307,  712, 4272, 1752, 2270,  758, 2269,  781,
#         4591, 2541, 1328, 4459, 4127, 4949, 1285, 2744,  333, 3126, 1132,
#          387, 3448, 1348, 1556,  776, 4886, 3062, 3642, 3445,  407,  943,
#          805, 2610, 1184, 3331, 1510,  731, 3111, 3542, 3551, 2934, 4289,
#         2475, 2849,  733, 2907, 1763, 2103,  301, 2638, 3568, 4775, 1968,
#         2532, 3260, 2570, 3613, 3263, 3193, 1303, 1587, 1248,  924, 1119,
#          825, 2443,  197, 4666,  682, 1092, 1525, 3672, 3852, 1615, 2362,
#         1305, 3404,  439, 1405,  266,   73, 3647, 2208,  818, 4473, 1274,
#         3631, 3513, 1474, 4683, 4260, 4906, 1989,  874, 4369,  335, 2616,
#          849,  526, 3447, 1092, 4559,  519,  480, 4224, 2452, 1289, 4920,
#         3067,   25, 1598, 3253, 2886, 4007, 1738, 4899, 1087, 4952, 2269,
#         2881, 2709, 3868, 3534, 3137, 3434, 4253, 3253, 4662, 2614, 4269,
#          705,  690, 4170, 4706, 3874, 2149, 2818,  557, 1016, 4496, 2802,
#         2366, 3653, 4522, 4807, 4021, 3978, 4739, 2221, 1065, 2983,  329,
#         3864,  891, 1442, 3171,  475, 2919, 2279, 3323, 3093, 2694, 2910,
#         3906, 4368,  582, 3731, 3493, 4369, 1781, 4567, 3676,  222,  951,
#         1866, 4619, 1463, 1424,  301, 3818,  318, 3659, 3845, 3893,  565,
#         3574, 1642,  927,  655, 3475,  165,  371, 2974, 2487, 3136, 2819,
#         3488, 4715,  925, 2064, 3878, 4618, 1097, 4874, 1873,  750, 4724,
#         1856, 2426, 1889, 1265, 3491,  789, 1452, 4061, 1221, 1830,   57,
#         4470, 2384, 2729,  139, 2146, 4606, 1854, 2588, 4491, 4762, 2327,
#         3787, 2093, 2567, 2086,  501, 3049, 1298, 1729,  873, 4520,  744,
#         3317, 4206, 3738,  726, 3447, 2877, 1582, 1729,  443, 1454, 3803,
#         3674,  644,  709, 3767, 2496, 1536, 1862, 4067, 3432, 3374,  185,
#          484, 2416, 4959,  318, 3320, 2001, 3373, 2390, 4035, 3039, 1391,
#         3192,  779,  146,  777, 2478, 4902, 3439,  725, 4707, 4979, 2536,
#          212, 3045, 1908,  399, 1307,  585, 3979, 2043, 4132, 2324, 4046,
#         3644, 3329,  490, 4361, 2305, 2473, 3598,  364,  775, 1472,  281,
#          177, 2535, 3309, 3827,  157, 4094, 1877,  415, 4935, 1298,  433,
#           57, 3673, 2844,  455, 3605,  893, 3328, 1543, 1091, 3673, 1100,
#         4017, 2139, 3712, 3446, 1629, 1093, 3888, 3408,  593, 1788, 3029,
#         3001,  547, 4702,  425, 4283, 2398, 2713, 3890, 1051, 2865, 4818,
#         3184, 1868,   38,  451, 4392,   20,  269,  480, 1006, 3104, 2426,
#         2670,  914, 4297, 2116, 2957, 3239,  610,  162, 2315,  935, 2980,
#         3812, 4358,  945, 1091,  969, 3492, 1735, 2134, 4044, 3971, 2510,
#         2436, 2240, 3822, 4452, 1776, 2511, 3456, 3189, 1805,  890,  507,
#         3253, 1357, 1528, 1620, 1674, 4071, 4849, 3760, 2173, 2203, 3136,
#         2760, 3684, 2075, 2535,  225,  531,  307, 3987, 3751, 2331, 4583,
#         2113, 4339, 4669,  862, 3905,  200, 4924, 3301, 4789, 4977, 2891,
#         1221, 3983, 4383,  274, 3712, 2333, 2513, 2502, 1851,  648, 3438,
#          266, 3696, 3775, 4211, 2740, 2816, 3416, 1037,  407, 3385, 4295,
#         4505, 3820, 2794, 3944, 3377,  491, 3802, 2856,  326, 3027, 2232,
#         1306, 2947,  586, 1623, 2938, 2124, 2327, 1457, 4626, 3013, 2208,
#          959, 1953, 4336, 4101, 1455,  986, 1104, 3850, 1642, 1428, 1025,
#          465, 3053, 2304, 3649, 1725, 3874,  847,  490, 2183,  250,  137,
#         3489, 1852, 3070, 2994,  694, 2502, 4988,  619, 4897,  437, 2358,
#         2258,  204, 4699, 3148, 3535, 4623, 2007, 3344,  819, 1610, 3472,
#         1714, 4454, 1662,  479,  118,  152, 1981, 2433, 3101, 2056, 3506,
#         4373, 2246, 2818, 3361, 2030,  794, 1607, 1173, 1821, 2181, 4585,
#         3686, 3886, 1332, 1834, 3724, 1572, 4275, 4012, 3313, 1483, 1374,
#         3994, 4780, 3476, 4760, 3442, 2090, 2957, 2538, 2958,  118, 3297,
#         4630, 2351,  285, 2617, 4209,  601, 2712,  940, 4297, 2228, 1369,
#         3920,  241,  379, 4545, 4910, 4579, 3902, 3142, 1810, 2752]),
#  array([ 685, 4861, 4941, ..., 2116, 3528, 1126]),
#  array([  81, 2552,  556, ..., 2112, 1261,   39]),
#  array([4435,  899, 1959, ...,   37, 3592,  678]),
#  array([4848, 4613, 4630, ..., 3523, 2209,  473])]

# %%
def insertion_sort(arr):
    n = len(arr)
    comparison_count = 0
    
    #checking for array size
    if (n>1): 
        for i in range (1,n):
            for j in range (i,0,-1):
                comparison_count+=1
                
                #condition for swapping 
                if(arr[j]<arr[j-1]):
                    
                    #in-place swapping
                    arr[j],arr[j-1] = arr[j-1],arr[j] 
                else:
                    break
    print(f"Comparison Count: {comparison_count}")
    # print(arr) - use this to remove the array wrapper
    return arr

insertion_sort(random_array)
# Out:
# Comparison Count: 24727529
# array([    2,     2,     2, ...,  9995,  9996, 10000])
