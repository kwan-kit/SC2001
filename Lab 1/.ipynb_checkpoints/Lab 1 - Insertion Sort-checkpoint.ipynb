# %%
import numpy as np

#change the threshold to np.inf to print everything but maximum array size allowed for the browser data limit is 100,000
np.set_printoptions(threshold=1000)

# Function to generate a random array based on input size and max value
def generate_random_array(size, max_value):
    return np.random.randint(1, max_value + 1, size)

size = 10000
max_value = 10000
random_array = generate_random_array(size, max_value)

random_array
# Out:
# array([8540, 6958,  432, ..., 2165, 8642, 7257])

# %%
import numpy as np

# Function to generate the dataset with the arrays 
def generate_datasets(limit):
    dataset = []
    sizes = [1000,10000,100000,1000000,10000000] #size of the arrays
    for size in sizes:
        dataset.append(np.random.randint(1, limit + 1, size))
    return dataset

limit = 5000  # You can specify the limit here
datasets = generate_datasets(limit)
datasets
# Out:
# [array([4321, 3917, 1385, 4332, 4362, 3830, 2863, 1358, 2711, 3145, 1755,
#         3946, 3697, 4972, 4119, 2953, 2141, 4845, 2979, 1986, 1393, 4237,
#         4646, 3433, 2136, 1310,  645, 3993, 2746, 1931, 4023, 4096, 4980,
#         3389, 2050, 1946, 2115, 3929, 1302, 3564, 2656,  257, 3484, 2191,
#          445, 2612, 1297, 3479, 2893,  103, 4320,  731,  578, 1829, 4354,
#         1774, 3302, 2908, 2013, 2723, 1876, 3758,  356, 4617, 3538,  981,
#         4557, 1064, 3936, 1673, 1328,   94,  822,  669, 4465,  947, 2902,
#          651,   43, 1606, 4929, 1718, 2746,  721,  875,  692, 2539, 3697,
#         1087, 3874, 4381, 4305, 4866, 2288, 4902, 2202, 3705, 3776, 1687,
#          720,  644, 2991,  941, 3591, 1945, 2860, 1968, 2225, 3747, 4182,
#         1446,  119, 2125,  311, 2232,  341, 3721, 2537, 1838,  105, 4753,
#          928, 2865, 2783, 1988, 3677, 4469, 1919, 4671, 4040,  462, 1117,
#         1307, 3288, 1552,  360, 3724, 2338, 4201, 3664, 1625, 1488, 1927,
#         2792,  656, 4577, 3852, 4415, 2182, 1050, 3260,  191, 1428, 3797,
#          180, 3719, 3735, 1148, 4637, 2622, 1167, 1438, 3684, 2636, 2568,
#         1897,  929,  828, 3182,  154, 1615, 2330,  557,  816, 3035, 2102,
#         1289, 2361, 1747, 4592, 2804, 2356, 3005, 4411, 4239, 1458, 1864,
#         4345, 3140, 3836, 2912, 2048,  939, 2103,  241, 3872, 3096, 2999,
#         4181, 2892, 2983, 1565, 2411,  466,  760, 4661, 4619, 3000, 3709,
#          481, 3719, 4183,  519, 1737, 3724, 1461,  382,  267, 2426, 3182,
#         1371, 4865, 1383, 4724, 1446, 4772,  494, 2627, 2105, 4148, 2128,
#         2899, 1349, 1349, 2701, 4972,  353, 2304, 1879, 4137, 1065, 1667,
#         2592, 4607, 2066, 1831, 3712, 2856, 2195, 4347, 4089, 1573,   19,
#          997, 3987,  546, 2126, 1734, 4557,  161, 2464,  977,   27, 2563,
#         4023, 2588,  681, 4842, 3682, 1477, 4846,  472, 1750,  346,  387,
#          432,  523,   28, 2646, 3320, 4260, 3205, 3037, 1418,  748, 2558,
#         3865,  906,   76, 1708, 4340,  407, 3057, 1552, 2771, 4680, 1444,
#         1553,  713, 1232,  415, 4708, 4260, 3209, 2540, 1099, 4638, 3946,
#          932,  816,  853, 3437, 3081, 2721, 4401, 2386,  599, 4543,  379,
#         4136,  782, 3728, 2597,  923, 1320, 4237, 3111, 1468,  594, 4204,
#         4725, 1372,  138, 1925, 3381, 3517, 4696, 4103, 2375,  241, 1594,
#         1823, 4621, 4741, 3861, 4528,  669, 3230, 4823, 3197, 1323, 2534,
#         3586, 2322,  969, 1596, 1020, 4430, 3637, 4103, 1343, 2487, 4070,
#         1238, 2032, 3412, 2753, 3235,  186, 4009,    3, 1645,  410,  505,
#         4168, 3735,  433, 1089, 1252, 4661, 3336, 2381, 4723, 4301, 3644,
#         2606, 3185, 4278, 3204, 4658,  171, 2012, 2252, 4693, 3083, 2354,
#         3439, 3812, 3886, 3820, 4687, 1164, 3682,  136, 3655, 4491, 1388,
#         2152, 2241, 4898, 4900, 2877, 1008,  162, 4107, 4575, 4618, 2611,
#         1124, 3615, 4906, 1091, 1589, 2956, 1066, 4554, 2860, 3389,  595,
#         2331,  704, 1304, 1244, 3668,  560, 1910, 3811, 2556, 3441, 2396,
#         2568, 3507, 4382, 3926,  181, 3041, 1407,  334, 2768, 1683,  185,
#         2622, 2177, 3094, 3479, 1865, 1274, 2544, 2467, 2738, 4703,  181,
#         2171, 2872, 4000, 4248, 2920, 4498,  441,  302,  388, 1823, 1405,
#         2049,  173, 3327, 1484, 4124,   65, 3170, 2187, 3820, 3846,  663,
#         4478, 2032, 3450,  818, 1362, 3135, 2610,  913, 4117, 4136, 2856,
#         2259, 4349, 1961, 4122, 2245, 4109, 2472, 4080, 4860,  767, 2218,
#         1485, 4746, 4943, 4294, 1948, 3733, 4151, 3421, 3658, 4610,  583,
#          799, 3281, 2086, 3889, 1392,  406, 3711, 2806, 2899, 3870, 1985,
#         1713, 4377, 4658, 2055, 1538, 1062,  776, 4003,  840, 4809,  613,
#         2775,  933,  381, 1992, 3628, 3395, 1578,  277, 1115, 1894, 3979,
#         2032, 2769, 2872, 1973,  728, 4282,  433, 1999, 2112, 2649, 3941,
#         4558, 3590,  526, 3971, 3880, 3858,  876, 2402, 2820,  927,   69,
#         1777, 3877, 3953, 2356, 2684, 2818, 1035, 2329, 3735, 3736,  938,
#         4419, 3203, 1190, 1901, 1198,  936,  970, 1652, 2781, 1618,  349,
#         4099, 2544,  775, 1393, 2315, 2209, 4273, 4837, 2217, 2868]),
#  array([ 506, 4513, 3572, ..., 2535, 1488, 4545]),
#  array([4155, 2781, 3878, ..., 3011, 3510, 2964]),
#  array([ 676, 2460, 1121, ..., 2801, 1014, 3441]),
#  array([3492, 3160, 3165, ..., 2987, 3007, 2621])]

# %%
def insertion_sort(arr):
    n = len(arr)
    comparison_count = 0
    
    #checking for array size
    if (n>1): 
        for i in range (1,n):
            for j in range (i,0,-1):
                comparison_count+=1
                
                #condition for swapping 
                if(arr[j]<arr[j-1]):
                    
                    #in-place swapping
                    arr[j],arr[j-1] = arr[j-1],arr[j] 
                else:
                    break
    print(f"Comparison Count: {comparison_count}")
    # print(arr) - use this to remove the array wrapper
    return arr

insertion_sort(random_array)
# Out:
# Comparison Count: 9999
# array([    2,     2,     8, ...,  9999,  9999, 10000])
